# %%
# %%
# Key features (include opponent's as well)
#   - Home vs. Away vs. Neutral
#   - Offensive Eff, or Offensive eFG%
#   - Turnover Percentage
#   - Rebounding
#   - Free Throws
#   - Seniority (collective games played for team?)
#   - Streak (last 5 games result)


# %%
import pandas as pd
from datetime import datetime
from sportsipy.ncaab.boxscore import *
from sportsipy.ncaab.schedule import *
from sportsipy.ncaab.teams import *
from sportsipy.ncaab.conferences import *
import seaborn as sns
import matplotlib as plt
from glob import glob
import os

# %%
# This loops through all files ending in .csv and concatenates them into a single df
from glob import glob
# grab all filenames ending with .csv
filenames = glob('../data/team_csvs/2019-2020v2/*.csv')
# loop through all file names adding the contents to one dataframe
ncaa_boxscore_df = pd.concat([pd.read_csv(f) for f in filenames], ignore_index = True)
# CSV now has all data in one spot, send to CSV
ncaa_boxscore_df.to_csv('../data/2019_ncaa_season_boxscores_v2.csv')

# %%
ncaa_boxscore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10247 entries, 0 to 10246
# Data columns (total 90 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              10247 non-null  int64
#  1   Unnamed: 0.1                            10247 non-null  object
#  2   away_assist_percentage                  10247 non-null  float64
#  3   away_assists                            10247 non-null  int64
#  4   away_block_percentage                   10247 non-null  float64
#  5   away_blocks                             10247 non-null  int64
#  6   away_defensive_rating                   10247 non-null  float64
#  7   away_defensive_rebound_percentage       10247 non-null  float64
#  8   away_defensive_rebounds                 10247 non-null  int64
#  9   away_effective_field_goal_percentage    10247 non-null  float64
# ...
