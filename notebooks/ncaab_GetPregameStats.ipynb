# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
from sportsipy.ncaab import boxscore
from sportsipy.ncaab.teams import Teams
from sportsipy.ncaab.teams import Team

# %%
# TODO: this will be where we loop through all files and get the CSV as a new dataframe
directory = '../data/team_csvs/2019-2020/'
for filename in os.scandir(directory):
    # create DF from CSV 
    try: 
        teamschedule_df = pd.read_csv(filename)

        #filename variable is an nt.DirEntry type. We need to convert it to string
        file_name = str(filename)
        print(file_name)
        # <DirEntry '109_Georgia_season_boxscores_2019.csv'>
        csvname = file_name[11:-2]
        print(csvname)

        # Now, we need to slice the string in a sustainable way. We'll slice out everything up to and including the first underscore
        file_name = file_name.split('_', 1)
        print(file_name)
        # ["<DirEntry '109", "Georgia_season_boxscores_2019.csv'>"]


        file_name = file_name[1]
        print(file_name)
        # Georgia_season_boxscores_2019.csv'>


        #next we extract team name and season - we know that everything after the name is constant for all files
        team_name = file_name[:-28]
        season = file_name[-10:-6]
        print(team_name)
        print(season)
        print('getting team abbreviation')
        for team in Teams(season):
            if team.name == team_name:
                abbrev = team.abbreviation
                break
            
        print (abbrev)
        teamschedule_df.rename(columns={'Unnamed: 0': 'boxscore'}, inplace=True)
        teamschedule_df['game_number'] = teamschedule_df.index

        # Conditional column - we have a pair of criteria that tell us if a given game is home based on the winner of the game (home vs. away) and 
        # the abbreviation of the winning team
        teamschedule_df['{}_homegame'.format(abbrev)] = (teamschedule_df['winner'] == 'Home') & (teamschedule_df['winning_abbr'] == abbrev)
        teamschedule_df['{}_homegame2'.format(abbrev)] = (teamschedule_df['winner'] == 'Away') & (teamschedule_df['winning_abbr'] != abbrev)

        # set team_abbrev_home to True if either of the home game criteria that we ran above are true
        teamschedule_df['{}_home'.format(abbrev)] = (teamschedule_df['{}_homegame'.format(abbrev)] == True) | (teamschedule_df['{}_homegame2'.format(abbrev)] == True)

        # Make the game location (from perspective of the team) equal to Home if the team_abbrev_home column is True, otherwise make it away
        teamschedule_df['{}_location'.format(abbrev)] = teamschedule_df.apply(lambda x: 'Home' if x['{}_home'.format(abbrev)] == True else 'Away', axis=1)

        # Create a column with True/False based on whether the team won their game. This will be used later to calc win percentage
        teamschedule_df['team_win_bool'] = (teamschedule_df['winning_abbr'] == abbrev)

        # Set each game stat equal to the home team stat if they played at home, otherwise set to the away team stat
        teamschedule_df['total_threes_made'] = teamschedule_df.apply(lambda x: x['home_three_point_field_goals'] if x['{}_home'.format(abbrev)] == True else x['away_three_point_field_goals'], axis=1)
        teamschedule_df['total_2pt_made'] = teamschedule_df.apply(lambda x: x['home_two_point_field_goals'] if x['{}_home'.format(abbrev)] == True else x['away_two_point_field_goals'], axis=1)
        teamschedule_df['total_fg_attempts'] = teamschedule_df.apply(lambda x: x['home_field_goal_attempts'] if x['{}_home'.format(abbrev)] == True else x['away_field_goal_attempts'], axis=1)

        # Do the same thing for rebounds instead of shooting
        # rebounding percentage = team rebounds / total rebounds
        teamschedule_df['team_rebounds'] = teamschedule_df.apply(lambda x: x['home_total_rebounds'] if x['{}_home'.format(abbrev)] == True else x['away_total_rebounds'], axis=1)
        teamschedule_df['total_rebounds'] = teamschedule_df['home_total_rebounds'] + teamschedule_df['away_total_rebounds']

        # Do the same thing for defensive statistics - remember we need to invert this
        teamschedule_df['total_opp_threes_made'] = teamschedule_df.apply(lambda x: x['away_three_point_field_goals'] if x['{}_home'.format(abbrev)] == True else x['home_three_point_field_goals'], axis=1)
        teamschedule_df['total_opp_2pt_made'] = teamschedule_df.apply(lambda x: x['away_two_point_field_goals'] if x['{}_home'.format(abbrev)] == True else x['home_two_point_field_goals'], axis=1)
        teamschedule_df['total_opp_fg_attempts'] = teamschedule_df.apply(lambda x: x['away_field_goal_attempts'] if x['{}_home'.format(abbrev)] == True else x['home_field_goal_attempts'], axis=1)

        #finally, calculate the rolling win percentage
        # adding 1 to game number so that we can easily calculate the wins and losses
        teamschedule_df['team_wins'] = 0
        teamschedule_df['team_losses'] = 0
        teamschedule_df['team_wins'] = teamschedule_df.apply(lambda x: x['team_wins'] + 1 if x['team_win_bool'] == True else x['team_wins'], axis = 1)
        teamschedule_df['team_losses'] = teamschedule_df.apply(lambda x: x['team_losses'] + 1 if x['team_win_bool'] == False else x['team_losses'], axis = 1)

        #calculate the cumulative pregame stats heading in to each game
        teamschedule_df['pregame_total_threes_made'] = teamschedule_df.total_threes_made.cumsum() - teamschedule_df.total_threes_made
        teamschedule_df['pregame_total_2pt_made'] = teamschedule_df.total_2pt_made.cumsum() - teamschedule_df.total_2pt_made
        teamschedule_df['pregame_total_fg_attempts'] = teamschedule_df.total_fg_attempts.cumsum() - teamschedule_df.total_fg_attempts

        #calculate the actual target statistic which is eFG 
        teamschedule_df['pregame_eFG'] = (teamschedule_df.pregame_total_2pt_made + (teamschedule_df.pregame_total_threes_made * 1.5)) / teamschedule_df.pregame_total_fg_attempts

        #calculate the cumulative rebound percentage
        teamschedule_df['pregame_team_rebounds'] = teamschedule_df.team_rebounds.cumsum() - teamschedule_df.team_rebounds
        teamschedule_df['pregame_total_rebounds'] = teamschedule_df.total_rebounds.cumsum() - teamschedule_df.total_rebounds
        teamschedule_df['pregame_rebound_percentage'] = teamschedule_df.pregame_team_rebounds / teamschedule_df.pregame_total_rebounds


        #calculate the cumulative defensive statistic
        teamschedule_df['pregame_total_opp_threes_made'] = teamschedule_df.total_opp_threes_made.cumsum() - teamschedule_df.total_opp_threes_made
        teamschedule_df['pregame_total_opp_2pt_made'] = teamschedule_df.total_opp_2pt_made.cumsum() - teamschedule_df.total_opp_2pt_made
        teamschedule_df['pregame_total_opp_fg_attempts'] = teamschedule_df.total_opp_fg_attempts.cumsum() - teamschedule_df.total_opp_fg_attempts

        # calculate the defensive eFG - aka opponents eFG
        teamschedule_df['pregame_eFG_allowed'] = (teamschedule_df.pregame_total_opp_2pt_made + (teamschedule_df.pregame_total_opp_threes_made * 1.5)) / teamschedule_df.pregame_total_opp_fg_attempts

        #calculate the pregame win percentage - it's the total wins after the game, minus result of game (loss would have no impact on total wins)
        # minus total losses after game (win would have no impact) divided by the sum of the two
        teamschedule_df['pregame_win_percentage'] = (teamschedule_df.team_wins.cumsum() - teamschedule_df.team_wins) / ((teamschedule_df.team_wins.cumsum() - teamschedule_df.team_wins) + (teamschedule_df.team_losses.cumsum() - teamschedule_df.team_losses))



        print('dataframe complete')

        # Overwrite the CSV with the new dataframe containing stats
        teamschedule_df.to_csv('../data/team_csvs/2019-2020/{}'.format(csvname))
        print(team_name, ' CSV complete')
    except:
        print(team_name, 'error')
# Out:
# <DirEntry "'101_Furman_season_boxscores_2019.csv">
# '101_Furman_season_boxscores_2019.csv
# ['<DirEntry "\'101', 'Furman_season_boxscores_2019.csv">']
# Furman_season_boxscores_2019.csv">
# Furman
# 2019
# getting team abbreviation
# FURMAN
# dataframe complete
# Furman  CSV complete
# <DirEntry '100_Fresno State_season_boxscores_2019.csv'>
# 100_Fresno State_season_boxscores_2019.csv
# ["<DirEntry '100", "Fresno State_season_boxscores_2019.csv'>"]
# Fresno State_season_boxscores_2019.csv'>
# Fresno State
# 2019
# getting team abbreviation
# FRESNO-STATE
# dataframe complete
# Fresno State  CSV complete
# <DirEntry '101_Furman_season_boxscores_2019.csv'>
# 101_Furman_season_boxscores_2019.csv
# ["<DirEntry '101", "Furman_season_boxscores_2019.csv'>"]
# Furman_season_boxscores_2019.csv'>
# Furman
# 2019
# getting team abbreviation
# FURMAN
# dataframe complete
# Furman  CSV complete
# <DirEntry '102_Gardner-Webb_season_boxscores_2019.csv'>
# 102_Gardner-Webb_season_boxscores_2019.csv
# ["<DirEntry '102", "Gardner-Webb_season_boxscores_2019.csv'>"]
# Gardner-Webb_season_boxscores_2019.csv'>
# Gardner-Webb
# 2019
# getting team abbreviation
# GARDNER-WEBB
# dataframe complete
# Gardner-Webb  CSV complete
# <DirEntry '103_George Mason_season_boxscores_2019.csv'>
# 103_George Mason_season_boxscores_2019.csv
# ["<DirEntry '103", "George Mason_season_boxscores_2019.csv'>"]
# George Mason_season_boxscores_2019.csv'>
# George Mason
# 2019
# getting team abbreviation
# GEORGE-MASON
# dataframe complete
# George Mason  CSV complete
# <DirEntry '104_George Washington_season_boxscores_2019.csv'>
# 104_George Washington_season_boxscores_2019.csv
# ["<DirEntry '104", "George Washington_season_boxscores_2019.csv'>"]
# George Washington_season_boxscores_2019.csv'>
# George Washington
# 2019
# getting team abbreviation
# GEORGE-WASHINGTON
# dataframe complete
# George Washington  CSV complete
# <DirEntry '105_Georgetown_season_boxscores_2019.csv'>
# 105_Georgetown_season_boxscores_2019.csv
# ["<DirEntry '105", "Georgetown_season_boxscores_2019.csv'>"]
# Georgetown_season_boxscores_2019.csv'>
# Georgetown
# 2019
# getting team abbreviation
# GEORGETOWN
# dataframe complete
# Georgetown  CSV complete
# <DirEntry '106_Georgia Southern_season_boxscores_2019.csv'>
# 106_Georgia Southern_season_boxscores_2019.csv
# ["<DirEntry '106", "Georgia Southern_season_boxscores_2019.csv'>"]
# Georgia Southern_season_boxscores_2019.csv'>
# Georgia Southern
# 2019
# getting team abbreviation
# GEORGIA-SOUTHERN
# dataframe complete
# Georgia Southern  CSV complete
# <DirEntry '107_Georgia State_season_boxscores_2019.csv'>
# 107_Georgia State_season_boxscores_2019.csv
# ["<DirEntry '107", "Georgia State_season_boxscores_2019.csv'>"]
# Georgia State_season_boxscores_2019.csv'>
# Georgia State
# 2019
# getting team abbreviation
# GEORGIA-STATE
# dataframe complete
# Georgia State  CSV complete
# <DirEntry '108_Georgia Tech_season_boxscores_2019.csv'>
# 108_Georgia Tech_season_boxscores_2019.csv
# ["<DirEntry '108", "Georgia Tech_season_boxscores_2019.csv'>"]
# Georgia Tech_season_boxscores_2019.csv'>
# Georgia Tech
# 2019
# getting team abbreviation
# GEORGIA-TECH
# dataframe complete
# Georgia Tech  CSV complete
# <DirEntry '109_Georgia_season_boxscores_2019.csv'>
# 109_Georgia_season_boxscores_2019.csv
# ["<DirEntry '109", "Georgia_season_boxscores_2019.csv'>"]
# Georgia_season_boxscores_2019.csv'>
# Georgia
# 2019
# getting team abbreviation
# GEORGIA
# dataframe complete
# Georgia  CSV complete
# <DirEntry '10_American_season_boxscores_2019.csv'>
# 10_American_season_boxscores_2019.csv
# ["<DirEntry '10", "American_season_boxscores_2019.csv'>"]
# American_season_boxscores_2019.csv'>
# American
# 2019
# getting team abbreviation
# AMERICAN
# dataframe complete
# American  CSV complete
# <DirEntry '110_Gonzaga_season_boxscores_2019.csv'>
# 110_Gonzaga_season_boxscores_2019.csv
# ["<DirEntry '110", "Gonzaga_season_boxscores_2019.csv'>"]
# Gonzaga_season_boxscores_2019.csv'>
# Gonzaga
# 2019
# getting team abbreviation
# GONZAGA
# dataframe complete
# Gonzaga  CSV complete
# <DirEntry '111_Grambling_season_boxscores_2019.csv'>
# 111_Grambling_season_boxscores_2019.csv
# ["<DirEntry '111", "Grambling_season_boxscores_2019.csv'>"]
# Grambling_season_boxscores_2019.csv'>
# Grambling
# 2019
# getting team abbreviation
# GRAMBLING
# dataframe complete
# Grambling  CSV complete
# <DirEntry '112_Grand Canyon_season_boxscores_2019.csv'>
# 112_Grand Canyon_season_boxscores_2019.csv
# ["<DirEntry '112", "Grand Canyon_season_boxscores_2019.csv'>"]
# Grand Canyon_season_boxscores_2019.csv'>
# Grand Canyon
# 2019
# getting team abbreviation
# GRAND-CANYON
# dataframe complete
# Grand Canyon  CSV complete
# <DirEntry '113_Green Bay_season_boxscores_2019.csv'>
# 113_Green Bay_season_boxscores_2019.csv
# ["<DirEntry '113", "Green Bay_season_boxscores_2019.csv'>"]
# Green Bay_season_boxscores_2019.csv'>
# Green Bay
# 2019
# getting team abbreviation
# GREEN-BAY
# dataframe complete
# Green Bay  CSV complete
# <DirEntry '114_Hampton_season_boxscores_2019.csv'>
# 114_Hampton_season_boxscores_2019.csv
# ["<DirEntry '114", "Hampton_season_boxscores_2019.csv'>"]
# Hampton_season_boxscores_2019.csv'>
# Hampton
# 2019
# getting team abbreviation
# HAMPTON
# dataframe complete
# Hampton  CSV complete
# <DirEntry '115_Hartford_season_boxscores_2019.csv'>
# 115_Hartford_season_boxscores_2019.csv
# ["<DirEntry '115", "Hartford_season_boxscores_2019.csv'>"]
# Hartford_season_boxscores_2019.csv'>
# Hartford
# 2019
# getting team abbreviation
# HARTFORD
# dataframe complete
# Hartford  CSV complete
# <DirEntry '116_Harvard_season_boxscores_2019.csv'>
# 116_Harvard_season_boxscores_2019.csv
# ["<DirEntry '116", "Harvard_season_boxscores_2019.csv'>"]
# Harvard_season_boxscores_2019.csv'>
# Harvard
# 2019
# getting team abbreviation
# HARVARD
# dataframe complete
# Harvard  CSV complete
# <DirEntry '117_Hawaii_season_boxscores_2019.csv'>
# 117_Hawaii_season_boxscores_2019.csv
# ["<DirEntry '117", "Hawaii_season_boxscores_2019.csv'>"]
# Hawaii_season_boxscores_2019.csv'>
# Hawaii
# 2019
# getting team abbreviation
# HAWAII
# dataframe complete
# Hawaii  CSV complete
# <DirEntry '118_High Point_season_boxscores_2019.csv'>
# 118_High Point_season_boxscores_2019.csv
# ["<DirEntry '118", "High Point_season_boxscores_2019.csv'>"]
# High Point_season_boxscores_2019.csv'>
# High Point
# 2019
# getting team abbreviation
# HIGH-POINT
# dataframe complete
# High Point  CSV complete
# <DirEntry '119_Hofstra_season_boxscores_2019.csv'>
# 119_Hofstra_season_boxscores_2019.csv
# ["<DirEntry '119", "Hofstra_season_boxscores_2019.csv'>"]
# Hofstra_season_boxscores_2019.csv'>
# Hofstra
# 2019
# getting team abbreviation
# HOFSTRA
# dataframe complete
# Hofstra  CSV complete
# <DirEntry '11_Appalachian State_season_boxscores_2019.csv'>
# 11_Appalachian State_season_boxscores_2019.csv
# ["<DirEntry '11", "Appalachian State_season_boxscores_2019.csv'>"]
# Appalachian State_season_boxscores_2019.csv'>
# Appalachian State
# 2019
# getting team abbreviation
# APPALACHIAN-STATE
# dataframe complete
# Appalachian State  CSV complete
# <DirEntry '120_Holy Cross_season_boxscores_2019.csv'>
# 120_Holy Cross_season_boxscores_2019.csv
# ["<DirEntry '120", "Holy Cross_season_boxscores_2019.csv'>"]
# Holy Cross_season_boxscores_2019.csv'>
# Holy Cross
# 2019
# getting team abbreviation
# HOLY-CROSS
# dataframe complete
# Holy Cross  CSV complete
# <DirEntry '121_Houston Baptist_season_boxscores_2019.csv'>
# 121_Houston Baptist_season_boxscores_2019.csv
# ["<DirEntry '121", "Houston Baptist_season_boxscores_2019.csv'>"]
# Houston Baptist_season_boxscores_2019.csv'>
# Houston Baptist
# 2019
# getting team abbreviation
# HOUSTON-BAPTIST
# dataframe complete
# Houston Baptist  CSV complete
# <DirEntry '122_Houston_season_boxscores_2019.csv'>
# 122_Houston_season_boxscores_2019.csv
# ["<DirEntry '122", "Houston_season_boxscores_2019.csv'>"]
# Houston_season_boxscores_2019.csv'>
# Houston
# 2019
# getting team abbreviation
# HOUSTON
# dataframe complete
# Houston  CSV complete
# <DirEntry '123_Howard_season_boxscores_2019.csv'>
# 123_Howard_season_boxscores_2019.csv
# ["<DirEntry '123", "Howard_season_boxscores_2019.csv'>"]
# Howard_season_boxscores_2019.csv'>
# Howard
# 2019
# getting team abbreviation
# HOWARD
# dataframe complete
# Howard  CSV complete
# <DirEntry '124_Idaho State_season_boxscores_2019.csv'>
# 124_Idaho State_season_boxscores_2019.csv
# ["<DirEntry '124", "Idaho State_season_boxscores_2019.csv'>"]
# Idaho State_season_boxscores_2019.csv'>
# Idaho State
# 2019
# getting team abbreviation
# IDAHO-STATE
# dataframe complete
# Idaho State  CSV complete
# <DirEntry '125_Idaho_season_boxscores_2019.csv'>
# 125_Idaho_season_boxscores_2019.csv
# ["<DirEntry '125", "Idaho_season_boxscores_2019.csv'>"]
# Idaho_season_boxscores_2019.csv'>
# Idaho
# 2019
# getting team abbreviation
# IDAHO
# dataframe complete
# Idaho  CSV complete
# <DirEntry '126_Illinois-Chicago_season_boxscores_2019.csv'>
# 126_Illinois-Chicago_season_boxscores_2019.csv
# ["<DirEntry '126", "Illinois-Chicago_season_boxscores_2019.csv'>"]
# Illinois-Chicago_season_boxscores_2019.csv'>
# Illinois-Chicago
# 2019
# getting team abbreviation
# ILLINOIS-CHICAGO
# dataframe complete
# Illinois-Chicago  CSV complete
# <DirEntry '127_Illinois State_season_boxscores_2019.csv'>
# 127_Illinois State_season_boxscores_2019.csv
# ["<DirEntry '127", "Illinois State_season_boxscores_2019.csv'>"]
# Illinois State_season_boxscores_2019.csv'>
# Illinois State
# 2019
# getting team abbreviation
# ILLINOIS-STATE
# dataframe complete
# Illinois State  CSV complete
# <DirEntry '128_Illinois_season_boxscores_2019.csv'>
# 128_Illinois_season_boxscores_2019.csv
# ["<DirEntry '128", "Illinois_season_boxscores_2019.csv'>"]
# Illinois_season_boxscores_2019.csv'>
# Illinois
# 2019
# getting team abbreviation
# ILLINOIS
# dataframe complete
# Illinois  CSV complete
# <DirEntry '129_Incarnate Word_season_boxscores_2019.csv'>
# 129_Incarnate Word_season_boxscores_2019.csv
# ["<DirEntry '129", "Incarnate Word_season_boxscores_2019.csv'>"]
# Incarnate Word_season_boxscores_2019.csv'>
# Incarnate Word
# 2019
# getting team abbreviation
# INCARNATE-WORD
# dataframe complete
# Incarnate Word  CSV complete
# <DirEntry '12_Arizona State_season_boxscores_2019.csv'>
# 12_Arizona State_season_boxscores_2019.csv
# ["<DirEntry '12", "Arizona State_season_boxscores_2019.csv'>"]
# Arizona State_season_boxscores_2019.csv'>
# Arizona State
# 2019
# getting team abbreviation
# ARIZONA-STATE
# dataframe complete
# Arizona State  CSV complete
# <DirEntry '130_Indiana State_season_boxscores_2019.csv'>
# 130_Indiana State_season_boxscores_2019.csv
# ["<DirEntry '130", "Indiana State_season_boxscores_2019.csv'>"]
# Indiana State_season_boxscores_2019.csv'>
# Indiana State
# 2019
# getting team abbreviation
# INDIANA-STATE
# dataframe complete
# Indiana State  CSV complete
# <DirEntry '131_Indiana_season_boxscores_2019.csv'>
# 131_Indiana_season_boxscores_2019.csv
# ["<DirEntry '131", "Indiana_season_boxscores_2019.csv'>"]
# Indiana_season_boxscores_2019.csv'>
# Indiana
# 2019
# getting team abbreviation
# INDIANA
# dataframe complete
# Indiana  CSV complete
# <DirEntry '132_Iona_season_boxscores_2019.csv'>
# 132_Iona_season_boxscores_2019.csv
# ["<DirEntry '132", "Iona_season_boxscores_2019.csv'>"]
# Iona_season_boxscores_2019.csv'>
# Iona
# 2019
# getting team abbreviation
# IONA
# dataframe complete
# Iona  CSV complete
# <DirEntry '133_Iowa State_season_boxscores_2019.csv'>
# 133_Iowa State_season_boxscores_2019.csv
# ["<DirEntry '133", "Iowa State_season_boxscores_2019.csv'>"]
# Iowa State_season_boxscores_2019.csv'>
# Iowa State
# 2019
# getting team abbreviation
# IOWA-STATE
# dataframe complete
# Iowa State  CSV complete
# <DirEntry '134_Iowa_season_boxscores_2019.csv'>
# 134_Iowa_season_boxscores_2019.csv
# ["<DirEntry '134", "Iowa_season_boxscores_2019.csv'>"]
# Iowa_season_boxscores_2019.csv'>
# Iowa
# 2019
# getting team abbreviation
# IOWA
# dataframe complete
# Iowa  CSV complete
# <DirEntry '135_Purdue-Fort Wayne_season_boxscores_2019.csv'>
# 135_Purdue-Fort Wayne_season_boxscores_2019.csv
# ["<DirEntry '135", "Purdue-Fort Wayne_season_boxscores_2019.csv'>"]
# Purdue-Fort Wayne_season_boxscores_2019.csv'>
# Purdue-Fort Wayne
# 2019
# getting team abbreviation
# IPFW
# dataframe complete
# Purdue-Fort Wayne  CSV complete
# <DirEntry '136_IUPUI_season_boxscores_2019.csv'>
# 136_IUPUI_season_boxscores_2019.csv
# ["<DirEntry '136", "IUPUI_season_boxscores_2019.csv'>"]
# IUPUI_season_boxscores_2019.csv'>
# IUPUI
# 2019
# getting team abbreviation
# IUPUI
# dataframe complete
# IUPUI  CSV complete
# <DirEntry '137_Jackson State_season_boxscores_2019.csv'>
# 137_Jackson State_season_boxscores_2019.csv
# ["<DirEntry '137", "Jackson State_season_boxscores_2019.csv'>"]
# Jackson State_season_boxscores_2019.csv'>
# Jackson State
# 2019
# getting team abbreviation
# JACKSON-STATE
# dataframe complete
# Jackson State  CSV complete
# <DirEntry '138_Jacksonville State_season_boxscores_2019.csv'>
# 138_Jacksonville State_season_boxscores_2019.csv
# ["<DirEntry '138", "Jacksonville State_season_boxscores_2019.csv'>"]
# Jacksonville State_season_boxscores_2019.csv'>
# Jacksonville State
# 2019
# getting team abbreviation
# JACKSONVILLE-STATE
# dataframe complete
# Jacksonville State  CSV complete
# <DirEntry '139_Jacksonville_season_boxscores_2019.csv'>
# 139_Jacksonville_season_boxscores_2019.csv
# ["<DirEntry '139", "Jacksonville_season_boxscores_2019.csv'>"]
# Jacksonville_season_boxscores_2019.csv'>
# Jacksonville
# 2019
# getting team abbreviation
# JACKSONVILLE
# dataframe complete
# Jacksonville  CSV complete
# <DirEntry '13_Arizona_season_boxscores_2019.csv'>
# 13_Arizona_season_boxscores_2019.csv
# ["<DirEntry '13", "Arizona_season_boxscores_2019.csv'>"]
# Arizona_season_boxscores_2019.csv'>
# Arizona
# 2019
# getting team abbreviation
# ARIZONA
# dataframe complete
# Arizona  CSV complete
# <DirEntry '140_James Madison_season_boxscores_2019.csv'>
# 140_James Madison_season_boxscores_2019.csv
# ["<DirEntry '140", "James Madison_season_boxscores_2019.csv'>"]
# James Madison_season_boxscores_2019.csv'>
# James Madison
# 2019
# getting team abbreviation
# JAMES-MADISON
# dataframe complete
# James Madison  CSV complete
# <DirEntry '141_Kansas State_season_boxscores_2019.csv'>
# 141_Kansas State_season_boxscores_2019.csv
# ["<DirEntry '141", "Kansas State_season_boxscores_2019.csv'>"]
# Kansas State_season_boxscores_2019.csv'>
# Kansas State
# 2019
# getting team abbreviation
# KANSAS-STATE
# dataframe complete
# Kansas State  CSV complete
# <DirEntry '142_Kansas_season_boxscores_2019.csv'>
# 142_Kansas_season_boxscores_2019.csv
# ["<DirEntry '142", "Kansas_season_boxscores_2019.csv'>"]
# Kansas_season_boxscores_2019.csv'>
# Kansas
# 2019
# getting team abbreviation
# KANSAS
# dataframe complete
# Kansas  CSV complete
# <DirEntry '143_Kennesaw State_season_boxscores_2019.csv'>
# 143_Kennesaw State_season_boxscores_2019.csv
# ["<DirEntry '143", "Kennesaw State_season_boxscores_2019.csv'>"]
# Kennesaw State_season_boxscores_2019.csv'>
# Kennesaw State
# 2019
# getting team abbreviation
# KENNESAW-STATE
# dataframe complete
# Kennesaw State  CSV complete
# <DirEntry '144_Kent State_season_boxscores_2019.csv'>
# 144_Kent State_season_boxscores_2019.csv
# ["<DirEntry '144", "Kent State_season_boxscores_2019.csv'>"]
# Kent State_season_boxscores_2019.csv'>
# Kent State
# 2019
# getting team abbreviation
# KENT-STATE
# dataframe complete
# Kent State  CSV complete
# <DirEntry '145_Kentucky_season_boxscores_2019.csv'>
# 145_Kentucky_season_boxscores_2019.csv
# ["<DirEntry '145", "Kentucky_season_boxscores_2019.csv'>"]
# Kentucky_season_boxscores_2019.csv'>
# Kentucky
# 2019
# getting team abbreviation
# KENTUCKY
# dataframe complete
# Kentucky  CSV complete
# <DirEntry '146_La Salle_season_boxscores_2019.csv'>
# 146_La Salle_season_boxscores_2019.csv
# ["<DirEntry '146", "La Salle_season_boxscores_2019.csv'>"]
# La Salle_season_boxscores_2019.csv'>
# La Salle
# 2019
# getting team abbreviation
# LA-SALLE
# dataframe complete
# La Salle  CSV complete
# <DirEntry '147_Lafayette_season_boxscores_2019.csv'>
# 147_Lafayette_season_boxscores_2019.csv
# ["<DirEntry '147", "Lafayette_season_boxscores_2019.csv'>"]
# Lafayette_season_boxscores_2019.csv'>
# Lafayette
# 2019
# getting team abbreviation
# LAFAYETTE
# dataframe complete
# Lafayette  CSV complete
# <DirEntry '148_Lamar_season_boxscores_2019.csv'>
# 148_Lamar_season_boxscores_2019.csv
# ["<DirEntry '148", "Lamar_season_boxscores_2019.csv'>"]
# Lamar_season_boxscores_2019.csv'>
# Lamar
# 2019
# getting team abbreviation
# LAMAR
# dataframe complete
# Lamar  CSV complete
# <DirEntry '149_Lehigh_season_boxscores_2019.csv'>
# 149_Lehigh_season_boxscores_2019.csv
# ["<DirEntry '149", "Lehigh_season_boxscores_2019.csv'>"]
# Lehigh_season_boxscores_2019.csv'>
# Lehigh
# 2019
# getting team abbreviation
# LEHIGH
# dataframe complete
# Lehigh  CSV complete
# <DirEntry '14_Little Rock_season_boxscores_2019.csv'>
# 14_Little Rock_season_boxscores_2019.csv
# ["<DirEntry '14", "Little Rock_season_boxscores_2019.csv'>"]
# Little Rock_season_boxscores_2019.csv'>
# Little Rock
# 2019
# getting team abbreviation
# ARKANSAS-LITTLE-ROCK
# dataframe complete
# Little Rock  CSV complete
# <DirEntry '150_Liberty_season_boxscores_2019.csv'>
# 150_Liberty_season_boxscores_2019.csv
# ["<DirEntry '150", "Liberty_season_boxscores_2019.csv'>"]
# Liberty_season_boxscores_2019.csv'>
# Liberty
# 2019
# getting team abbreviation
# LIBERTY
# dataframe complete
# Liberty  CSV complete
# <DirEntry '151_Lipscomb_season_boxscores_2019.csv'>
# 151_Lipscomb_season_boxscores_2019.csv
# ["<DirEntry '151", "Lipscomb_season_boxscores_2019.csv'>"]
# Lipscomb_season_boxscores_2019.csv'>
# Lipscomb
# 2019
# getting team abbreviation
# LIPSCOMB
# dataframe complete
# Lipscomb  CSV complete
# <DirEntry '152_Cal State Long Beach_season_boxscores_2019.csv'>
# 152_Cal State Long Beach_season_boxscores_2019.csv
# ["<DirEntry '152", "Cal State Long Beach_season_boxscores_2019.csv'>"]
# Cal State Long Beach_season_boxscores_2019.csv'>
# Cal State Long Beach
# 2019
# getting team abbreviation
# LONG-BEACH-STATE
# dataframe complete
# Cal State Long Beach  CSV complete
# <DirEntry '153_Long Island University_season_boxscores_2019.csv'>
# 153_Long Island University_season_boxscores_2019.csv
# ["<DirEntry '153", "Long Island University_season_boxscores_2019.csv'>"]
# Long Island University_season_boxscores_2019.csv'>
# Long Island University
# 2019
# getting team abbreviation
# LONG-ISLAND-UNIVERSITY
# dataframe complete
# Long Island University  CSV complete
# <DirEntry '154_Longwood_season_boxscores_2019.csv'>
# 154_Longwood_season_boxscores_2019.csv
# ["<DirEntry '154", "Longwood_season_boxscores_2019.csv'>"]
# Longwood_season_boxscores_2019.csv'>
# Longwood
# 2019
# getting team abbreviation
# LONGWOOD
# dataframe complete
# Longwood  CSV complete
# <DirEntry '155_Louisiana_season_boxscores_2019.csv'>
# 155_Louisiana_season_boxscores_2019.csv
# ["<DirEntry '155", "Louisiana_season_boxscores_2019.csv'>"]
# Louisiana_season_boxscores_2019.csv'>
# Louisiana
# 2019
# getting team abbreviation
# LOUISIANA-LAFAYETTE
# dataframe complete
# Louisiana  CSV complete
# <DirEntry '156_Louisiana-Monroe_season_boxscores_2019.csv'>
# 156_Louisiana-Monroe_season_boxscores_2019.csv
# ["<DirEntry '156", "Louisiana-Monroe_season_boxscores_2019.csv'>"]
# Louisiana-Monroe_season_boxscores_2019.csv'>
# Louisiana-Monroe
# 2019
# getting team abbreviation
# LOUISIANA-MONROE
# dataframe complete
# Louisiana-Monroe  CSV complete
# <DirEntry '157_Louisiana State_season_boxscores_2019.csv'>
# 157_Louisiana State_season_boxscores_2019.csv
# ["<DirEntry '157", "Louisiana State_season_boxscores_2019.csv'>"]
# Louisiana State_season_boxscores_2019.csv'>
# Louisiana State
# 2019
# getting team abbreviation
# LOUISIANA-STATE
# dataframe complete
# Louisiana State  CSV complete
# <DirEntry '158_Louisiana Tech_season_boxscores_2019.csv'>
# 158_Louisiana Tech_season_boxscores_2019.csv
# ["<DirEntry '158", "Louisiana Tech_season_boxscores_2019.csv'>"]
# Louisiana Tech_season_boxscores_2019.csv'>
# Louisiana Tech
# 2019
# getting team abbreviation
# LOUISIANA-TECH
# dataframe complete
# Louisiana Tech  CSV complete
# <DirEntry '159_Louisville_season_boxscores_2019.csv'>
# 159_Louisville_season_boxscores_2019.csv
# ["<DirEntry '159", "Louisville_season_boxscores_2019.csv'>"]
# Louisville_season_boxscores_2019.csv'>
# Louisville
# 2019
# getting team abbreviation
# LOUISVILLE
# dataframe complete
# Louisville  CSV complete
# <DirEntry '15_Arkansas-Pine Bluff_season_boxscores_2019.csv'>
# 15_Arkansas-Pine Bluff_season_boxscores_2019.csv
# ["<DirEntry '15", "Arkansas-Pine Bluff_season_boxscores_2019.csv'>"]
# Arkansas-Pine Bluff_season_boxscores_2019.csv'>
# Arkansas-Pine Bluff
# 2019
# getting team abbreviation
# ARKANSAS-PINE-BLUFF
# dataframe complete
# Arkansas-Pine Bluff  CSV complete
# <DirEntry '160_Loyola (IL)_season_boxscores_2019.csv'>
# 160_Loyola (IL)_season_boxscores_2019.csv
# ["<DirEntry '160", "Loyola (IL)_season_boxscores_2019.csv'>"]
# Loyola (IL)_season_boxscores_2019.csv'>
# Loyola (IL)
# 2019
# getting team abbreviation
# LOYOLA-IL
# dataframe complete
# Loyola (IL)  CSV complete
# <DirEntry '161_Loyola Marymount_season_boxscores_2019.csv'>
# 161_Loyola Marymount_season_boxscores_2019.csv
# ["<DirEntry '161", "Loyola Marymount_season_boxscores_2019.csv'>"]
# Loyola Marymount_season_boxscores_2019.csv'>
# Loyola Marymount
# 2019
# getting team abbreviation
# LOYOLA-MARYMOUNT
# dataframe complete
# Loyola Marymount  CSV complete
# <DirEntry '162_Loyola (MD)_season_boxscores_2019.csv'>
# 162_Loyola (MD)_season_boxscores_2019.csv
# ["<DirEntry '162", "Loyola (MD)_season_boxscores_2019.csv'>"]
# Loyola (MD)_season_boxscores_2019.csv'>
# Loyola (MD)
# 2019
# getting team abbreviation
# LOYOLA-MD
# dataframe complete
# Loyola (MD)  CSV complete
# <DirEntry '163_Maine_season_boxscores_2019.csv'>
# 163_Maine_season_boxscores_2019.csv
# ["<DirEntry '163", "Maine_season_boxscores_2019.csv'>"]
# Maine_season_boxscores_2019.csv'>
# Maine
# 2019
# getting team abbreviation
# MAINE
# dataframe complete
# Maine  CSV complete
# <DirEntry '164_Manhattan_season_boxscores_2019.csv'>
# 164_Manhattan_season_boxscores_2019.csv
# ["<DirEntry '164", "Manhattan_season_boxscores_2019.csv'>"]
# Manhattan_season_boxscores_2019.csv'>
# Manhattan
# 2019
# getting team abbreviation
# MANHATTAN
# dataframe complete
# Manhattan  CSV complete
# <DirEntry '165_Marist_season_boxscores_2019.csv'>
# 165_Marist_season_boxscores_2019.csv
# ["<DirEntry '165", "Marist_season_boxscores_2019.csv'>"]
# Marist_season_boxscores_2019.csv'>
# Marist
# 2019
# getting team abbreviation
# MARIST
# dataframe complete
# Marist  CSV complete
# <DirEntry '166_Marquette_season_boxscores_2019.csv'>
# 166_Marquette_season_boxscores_2019.csv
# ["<DirEntry '166", "Marquette_season_boxscores_2019.csv'>"]
# Marquette_season_boxscores_2019.csv'>
# Marquette
# 2019
# getting team abbreviation
# MARQUETTE
# dataframe complete
# Marquette  CSV complete
# <DirEntry '167_Marshall_season_boxscores_2019.csv'>
# 167_Marshall_season_boxscores_2019.csv
# ["<DirEntry '167", "Marshall_season_boxscores_2019.csv'>"]
# Marshall_season_boxscores_2019.csv'>
# Marshall
# 2019
# getting team abbreviation
# MARSHALL
# dataframe complete
# Marshall  CSV complete
# <DirEntry '168_Maryland-Baltimore County_season_boxscores_2019.csv'>
# 168_Maryland-Baltimore County_season_boxscores_2019.csv
# ["<DirEntry '168", "Maryland-Baltimore County_season_boxscores_2019.csv'>"]
# Maryland-Baltimore County_season_boxscores_2019.csv'>
# Maryland-Baltimore County
# 2019
# getting team abbreviation
# MARYLAND-BALTIMORE-COUNTY
# dataframe complete
# Maryland-Baltimore County  CSV complete
# <DirEntry '169_Maryland-Eastern Shore_season_boxscores_2019.csv'>
# 169_Maryland-Eastern Shore_season_boxscores_2019.csv
# ["<DirEntry '169", "Maryland-Eastern Shore_season_boxscores_2019.csv'>"]
# Maryland-Eastern Shore_season_boxscores_2019.csv'>
# Maryland-Eastern Shore
# 2019
# getting team abbreviation
# MARYLAND-EASTERN-SHORE
# dataframe complete
# Maryland-Eastern Shore  CSV complete
# <DirEntry '16_Arkansas State_season_boxscores_2019.csv'>
# 16_Arkansas State_season_boxscores_2019.csv
# ["<DirEntry '16", "Arkansas State_season_boxscores_2019.csv'>"]
# Arkansas State_season_boxscores_2019.csv'>
# Arkansas State
# 2019
# getting team abbreviation
# ARKANSAS-STATE
# dataframe complete
# Arkansas State  CSV complete
# <DirEntry '170_Maryland_season_boxscores_2019.csv'>
# 170_Maryland_season_boxscores_2019.csv
# ["<DirEntry '170", "Maryland_season_boxscores_2019.csv'>"]
# Maryland_season_boxscores_2019.csv'>
# Maryland
# 2019
# getting team abbreviation
# MARYLAND
# dataframe complete
# Maryland  CSV complete
# <DirEntry '171_Massachusetts-Lowell_season_boxscores_2019.csv'>
# 171_Massachusetts-Lowell_season_boxscores_2019.csv
# ["<DirEntry '171", "Massachusetts-Lowell_season_boxscores_2019.csv'>"]
# Massachusetts-Lowell_season_boxscores_2019.csv'>
# Massachusetts-Lowell
# 2019
# getting team abbreviation
# MASSACHUSETTS-LOWELL
# dataframe complete
# Massachusetts-Lowell  CSV complete
# <DirEntry '172_Massachusetts_season_boxscores_2019.csv'>
# 172_Massachusetts_season_boxscores_2019.csv
# ["<DirEntry '172", "Massachusetts_season_boxscores_2019.csv'>"]
# Massachusetts_season_boxscores_2019.csv'>
# Massachusetts
# 2019
# getting team abbreviation
# MASSACHUSETTS
# dataframe complete
# Massachusetts  CSV complete
# <DirEntry '173_McNeese State_season_boxscores_2019.csv'>
# 173_McNeese State_season_boxscores_2019.csv
# ["<DirEntry '173", "McNeese State_season_boxscores_2019.csv'>"]
# McNeese State_season_boxscores_2019.csv'>
# McNeese State
# 2019
# getting team abbreviation
# MCNEESE-STATE
# dataframe complete
# McNeese State  CSV complete
# <DirEntry '174_Memphis_season_boxscores_2019.csv'>
# 174_Memphis_season_boxscores_2019.csv
# ["<DirEntry '174", "Memphis_season_boxscores_2019.csv'>"]
# Memphis_season_boxscores_2019.csv'>
# Memphis
# 2019
# getting team abbreviation
# MEMPHIS
# dataframe complete
# Memphis  CSV complete
# <DirEntry '175_Mercer_season_boxscores_2019.csv'>
# 175_Mercer_season_boxscores_2019.csv
# ["<DirEntry '175", "Mercer_season_boxscores_2019.csv'>"]
# Mercer_season_boxscores_2019.csv'>
# Mercer
# 2019
# getting team abbreviation
# MERCER
# dataframe complete
# Mercer  CSV complete
# <DirEntry '176_Miami (FL)_season_boxscores_2019.csv'>
# 176_Miami (FL)_season_boxscores_2019.csv
# ["<DirEntry '176", "Miami (FL)_season_boxscores_2019.csv'>"]
# Miami (FL)_season_boxscores_2019.csv'>
# Miami (FL)
# 2019
# getting team abbreviation
# MIAMI-FL
# dataframe complete
# Miami (FL)  CSV complete
# <DirEntry '177_Miami (OH)_season_boxscores_2019.csv'>
# 177_Miami (OH)_season_boxscores_2019.csv
# ["<DirEntry '177", "Miami (OH)_season_boxscores_2019.csv'>"]
# Miami (OH)_season_boxscores_2019.csv'>
# Miami (OH)
# 2019
# getting team abbreviation
# MIAMI-OH
# dataframe complete
# Miami (OH)  CSV complete
# <DirEntry '178_Michigan State_season_boxscores_2019.csv'>
# 178_Michigan State_season_boxscores_2019.csv
# ["<DirEntry '178", "Michigan State_season_boxscores_2019.csv'>"]
# Michigan State_season_boxscores_2019.csv'>
# Michigan State
# 2019
# getting team abbreviation
# MICHIGAN-STATE
# dataframe complete
# Michigan State  CSV complete
# <DirEntry '179_Michigan_season_boxscores_2019.csv'>
# 179_Michigan_season_boxscores_2019.csv
# ["<DirEntry '179", "Michigan_season_boxscores_2019.csv'>"]
# Michigan_season_boxscores_2019.csv'>
# Michigan
# 2019
# getting team abbreviation
# MICHIGAN
# dataframe complete
# Michigan  CSV complete
# <DirEntry '17_Arkansas_season_boxscores_2019.csv'>
# 17_Arkansas_season_boxscores_2019.csv
# ["<DirEntry '17", "Arkansas_season_boxscores_2019.csv'>"]
# Arkansas_season_boxscores_2019.csv'>
# Arkansas
# 2019
# getting team abbreviation
# ARKANSAS
# dataframe complete
# Arkansas  CSV complete
# <DirEntry '180_Middle Tennessee_season_boxscores_2019.csv'>
# 180_Middle Tennessee_season_boxscores_2019.csv
# ["<DirEntry '180", "Middle Tennessee_season_boxscores_2019.csv'>"]
# Middle Tennessee_season_boxscores_2019.csv'>
# Middle Tennessee
# 2019
# getting team abbreviation
# MIDDLE-TENNESSEE
# dataframe complete
# Middle Tennessee  CSV complete
# <DirEntry '181_Milwaukee_season_boxscores_2019.csv'>
# 181_Milwaukee_season_boxscores_2019.csv
# ["<DirEntry '181", "Milwaukee_season_boxscores_2019.csv'>"]
# Milwaukee_season_boxscores_2019.csv'>
# Milwaukee
# 2019
# getting team abbreviation
# MILWAUKEE
# dataframe complete
# Milwaukee  CSV complete
# <DirEntry '182_Minnesota_season_boxscores_2019.csv'>
# 182_Minnesota_season_boxscores_2019.csv
# ["<DirEntry '182", "Minnesota_season_boxscores_2019.csv'>"]
# Minnesota_season_boxscores_2019.csv'>
# Minnesota
# 2019
# getting team abbreviation
# MINNESOTA
# dataframe complete
# Minnesota  CSV complete
# <DirEntry '183_Mississippi State_season_boxscores_2019.csv'>
# 183_Mississippi State_season_boxscores_2019.csv
# ["<DirEntry '183", "Mississippi State_season_boxscores_2019.csv'>"]
# Mississippi State_season_boxscores_2019.csv'>
# Mississippi State
# 2019
# getting team abbreviation
# MISSISSIPPI-STATE
# dataframe complete
# Mississippi State  CSV complete
# <DirEntry '184_Mississippi Valley State_season_boxscores_2019.csv'>
# 184_Mississippi Valley State_season_boxscores_2019.csv
# ["<DirEntry '184", "Mississippi Valley State_season_boxscores_2019.csv'>"]
# Mississippi Valley State_season_boxscores_2019.csv'>
# Mississippi Valley State
# 2019
# getting team abbreviation
# MISSISSIPPI-VALLEY-STATE
# dataframe complete
# Mississippi Valley State  CSV complete
# <DirEntry '185_Mississippi_season_boxscores_2019.csv'>
# 185_Mississippi_season_boxscores_2019.csv
# ["<DirEntry '185", "Mississippi_season_boxscores_2019.csv'>"]
# Mississippi_season_boxscores_2019.csv'>
# Mississippi
# 2019
# getting team abbreviation
# MISSISSIPPI
# dataframe complete
# Mississippi  CSV complete
# <DirEntry '186_Kansas City_season_boxscores_2019.csv'>
# 186_Kansas City_season_boxscores_2019.csv
# ["<DirEntry '186", "Kansas City_season_boxscores_2019.csv'>"]
# Kansas City_season_boxscores_2019.csv'>
# Kansas City
# 2019
# getting team abbreviation
# MISSOURI-KANSAS-CITY
# dataframe complete
# Kansas City  CSV complete
# <DirEntry '187_Missouri State_season_boxscores_2019.csv'>
# 187_Missouri State_season_boxscores_2019.csv
# ["<DirEntry '187", "Missouri State_season_boxscores_2019.csv'>"]
# Missouri State_season_boxscores_2019.csv'>
# Missouri State
# 2019
# getting team abbreviation
# MISSOURI-STATE
# dataframe complete
# Missouri State  CSV complete
# <DirEntry '188_Missouri_season_boxscores_2019.csv'>
# 188_Missouri_season_boxscores_2019.csv
# ["<DirEntry '188", "Missouri_season_boxscores_2019.csv'>"]
# Missouri_season_boxscores_2019.csv'>
# Missouri
# 2019
# getting team abbreviation
# MISSOURI
# dataframe complete
# Missouri  CSV complete
# <DirEntry '189_Monmouth_season_boxscores_2019.csv'>
# 189_Monmouth_season_boxscores_2019.csv
# ["<DirEntry '189", "Monmouth_season_boxscores_2019.csv'>"]
# Monmouth_season_boxscores_2019.csv'>
# Monmouth
# 2019
# getting team abbreviation
# MONMOUTH
# dataframe complete
# Monmouth  CSV complete
# <DirEntry '18_Army_season_boxscores_2019.csv'>
# 18_Army_season_boxscores_2019.csv
# ["<DirEntry '18", "Army_season_boxscores_2019.csv'>"]
# Army_season_boxscores_2019.csv'>
# Army
# 2019
# getting team abbreviation
# ARMY
# dataframe complete
# Army  CSV complete
# <DirEntry '190_Montana State_season_boxscores_2019.csv'>
# 190_Montana State_season_boxscores_2019.csv
# ["<DirEntry '190", "Montana State_season_boxscores_2019.csv'>"]
# Montana State_season_boxscores_2019.csv'>
# Montana State
# 2019
# getting team abbreviation
# MONTANA-STATE
# dataframe complete
# Montana State  CSV complete
# <DirEntry '191_Montana_season_boxscores_2019.csv'>
# 191_Montana_season_boxscores_2019.csv
# ["<DirEntry '191", "Montana_season_boxscores_2019.csv'>"]
# Montana_season_boxscores_2019.csv'>
# Montana
# 2019
# getting team abbreviation
# MONTANA
# dataframe complete
# Montana  CSV complete
# <DirEntry '192_Morehead State_season_boxscores_2019.csv'>
# 192_Morehead State_season_boxscores_2019.csv
# ["<DirEntry '192", "Morehead State_season_boxscores_2019.csv'>"]
# Morehead State_season_boxscores_2019.csv'>
# Morehead State
# 2019
# getting team abbreviation
# MOREHEAD-STATE
# dataframe complete
# Morehead State  CSV complete
# <DirEntry '193_Morgan State_season_boxscores_2019.csv'>
# 193_Morgan State_season_boxscores_2019.csv
# ["<DirEntry '193", "Morgan State_season_boxscores_2019.csv'>"]
# Morgan State_season_boxscores_2019.csv'>
# Morgan State
# 2019
# getting team abbreviation
# MORGAN-STATE
# dataframe complete
# Morgan State  CSV complete
# <DirEntry "194_Mount St. Mary's_season_boxscores_2019.csv">
# 194_Mount St. Mary's_season_boxscores_2019.csv
# ['<DirEntry "194', 'Mount St. Mary\'s_season_boxscores_2019.csv">']
# Mount St. Mary's_season_boxscores_2019.csv">
# Mount St. Mary's
# 2019
# getting team abbreviation
# MOUNT-ST-MARYS
# dataframe complete
# Mount St. Mary's  CSV complete
# <DirEntry '195_Murray State_season_boxscores_2019.csv'>
# 195_Murray State_season_boxscores_2019.csv
# ["<DirEntry '195", "Murray State_season_boxscores_2019.csv'>"]
# Murray State_season_boxscores_2019.csv'>
# Murray State
# 2019
# getting team abbreviation
# MURRAY-STATE
# dataframe complete
# Murray State  CSV complete
# <DirEntry '196_Navy_season_boxscores_2019.csv'>
# 196_Navy_season_boxscores_2019.csv
# ["<DirEntry '196", "Navy_season_boxscores_2019.csv'>"]
# Navy_season_boxscores_2019.csv'>
# Navy
# 2019
# getting team abbreviation
# NAVY
# dataframe complete
# Navy  CSV complete
# <DirEntry '197_Omaha_season_boxscores_2019.csv'>
# 197_Omaha_season_boxscores_2019.csv
# ["<DirEntry '197", "Omaha_season_boxscores_2019.csv'>"]
# Omaha_season_boxscores_2019.csv'>
# Omaha
# 2019
# getting team abbreviation
# NEBRASKA-OMAHA
# dataframe complete
# Omaha  CSV complete
# <DirEntry '198_Nebraska_season_boxscores_2019.csv'>
# 198_Nebraska_season_boxscores_2019.csv
# ["<DirEntry '198", "Nebraska_season_boxscores_2019.csv'>"]
# Nebraska_season_boxscores_2019.csv'>
# Nebraska
# 2019
# getting team abbreviation
# NEBRASKA
# dataframe complete
# Nebraska  CSV complete
# <DirEntry '199_Nevada-Las Vegas_season_boxscores_2019.csv'>
# 199_Nevada-Las Vegas_season_boxscores_2019.csv
# ["<DirEntry '199", "Nevada-Las Vegas_season_boxscores_2019.csv'>"]
# Nevada-Las Vegas_season_boxscores_2019.csv'>
# Nevada-Las Vegas
# 2019
# getting team abbreviation
# NEVADA-LAS-VEGAS
# dataframe complete
# Nevada-Las Vegas  CSV complete
# <DirEntry '19_Auburn_season_boxscores_2019.csv'>
# 19_Auburn_season_boxscores_2019.csv
# ["<DirEntry '19", "Auburn_season_boxscores_2019.csv'>"]
# Auburn_season_boxscores_2019.csv'>
# Auburn
# 2019
# getting team abbreviation
# AUBURN
# dataframe complete
# Auburn  CSV complete
# <DirEntry '1_Abilene Christian_season_boxscores_2019.csv'>
# 1_Abilene Christian_season_boxscores_2019.csv
# ["<DirEntry '1", "Abilene Christian_season_boxscores_2019.csv'>"]
# Abilene Christian_season_boxscores_2019.csv'>
# Abilene Christian
# 2019
# getting team abbreviation
# ABILENE-CHRISTIAN
# dataframe complete
# Abilene Christian  CSV complete
# <DirEntry '200_Nevada_season_boxscores_2019.csv'>
# 200_Nevada_season_boxscores_2019.csv
# ["<DirEntry '200", "Nevada_season_boxscores_2019.csv'>"]
# Nevada_season_boxscores_2019.csv'>
# Nevada
# 2019
# getting team abbreviation
# NEVADA
# dataframe complete
# Nevada  CSV complete
# <DirEntry '201_New Hampshire_season_boxscores_2019.csv'>
# 201_New Hampshire_season_boxscores_2019.csv
# ["<DirEntry '201", "New Hampshire_season_boxscores_2019.csv'>"]
# New Hampshire_season_boxscores_2019.csv'>
# New Hampshire
# 2019
# getting team abbreviation
# NEW-HAMPSHIRE
# dataframe complete
# New Hampshire  CSV complete
# <DirEntry '202_New Mexico State_season_boxscores_2019.csv'>
# 202_New Mexico State_season_boxscores_2019.csv
# ["<DirEntry '202", "New Mexico State_season_boxscores_2019.csv'>"]
# New Mexico State_season_boxscores_2019.csv'>
# New Mexico State
# 2019
# getting team abbreviation
# NEW-MEXICO-STATE
# dataframe complete
# New Mexico State  CSV complete
# <DirEntry '203_New Mexico_season_boxscores_2019.csv'>
# 203_New Mexico_season_boxscores_2019.csv
# ["<DirEntry '203", "New Mexico_season_boxscores_2019.csv'>"]
# New Mexico_season_boxscores_2019.csv'>
# New Mexico
# 2019
# getting team abbreviation
# NEW-MEXICO
# dataframe complete
# New Mexico  CSV complete
# <DirEntry '204_New Orleans_season_boxscores_2019.csv'>
# 204_New Orleans_season_boxscores_2019.csv
# ["<DirEntry '204", "New Orleans_season_boxscores_2019.csv'>"]
# New Orleans_season_boxscores_2019.csv'>
# New Orleans
# 2019
# getting team abbreviation
# NEW-ORLEANS
# dataframe complete
# New Orleans  CSV complete
# <DirEntry '205_Niagara_season_boxscores_2019.csv'>
# 205_Niagara_season_boxscores_2019.csv
# ["<DirEntry '205", "Niagara_season_boxscores_2019.csv'>"]
# Niagara_season_boxscores_2019.csv'>
# Niagara
# 2019
# getting team abbreviation
# NIAGARA
# dataframe complete
# Niagara  CSV complete
# <DirEntry '206_Nicholls State_season_boxscores_2019.csv'>
# 206_Nicholls State_season_boxscores_2019.csv
# ["<DirEntry '206", "Nicholls State_season_boxscores_2019.csv'>"]
# Nicholls State_season_boxscores_2019.csv'>
# Nicholls State
# 2019
# getting team abbreviation
# NICHOLLS-STATE
# dataframe complete
# Nicholls State  CSV complete
# <DirEntry '207_NJIT_season_boxscores_2019.csv'>
# 207_NJIT_season_boxscores_2019.csv
# ["<DirEntry '207", "NJIT_season_boxscores_2019.csv'>"]
# NJIT_season_boxscores_2019.csv'>
# NJIT
# 2019
# getting team abbreviation
# NJIT
# dataframe complete
# NJIT  CSV complete
# <DirEntry '208_Norfolk State_season_boxscores_2019.csv'>
# 208_Norfolk State_season_boxscores_2019.csv
# ["<DirEntry '208", "Norfolk State_season_boxscores_2019.csv'>"]
# Norfolk State_season_boxscores_2019.csv'>
# Norfolk State
# 2019
# getting team abbreviation
# NORFOLK-STATE
# dataframe complete
# Norfolk State  CSV complete
# <DirEntry '209_North Alabama_season_boxscores_2019.csv'>
# 209_North Alabama_season_boxscores_2019.csv
# ["<DirEntry '209", "North Alabama_season_boxscores_2019.csv'>"]
# North Alabama_season_boxscores_2019.csv'>
# North Alabama
# 2019
# getting team abbreviation
# NORTH-ALABAMA
# dataframe complete
# North Alabama  CSV complete
# <DirEntry '20_Austin Peay_season_boxscores_2019.csv'>
# 20_Austin Peay_season_boxscores_2019.csv
# ["<DirEntry '20", "Austin Peay_season_boxscores_2019.csv'>"]
# Austin Peay_season_boxscores_2019.csv'>
# Austin Peay
# 2019
# getting team abbreviation
# AUSTIN-PEAY
# dataframe complete
# Austin Peay  CSV complete
# <DirEntry '210_UNC Asheville_season_boxscores_2019.csv'>
# 210_UNC Asheville_season_boxscores_2019.csv
# ["<DirEntry '210", "UNC Asheville_season_boxscores_2019.csv'>"]
# UNC Asheville_season_boxscores_2019.csv'>
# UNC Asheville
# 2019
# getting team abbreviation
# NORTH-CAROLINA-ASHEVILLE
# dataframe complete
# UNC Asheville  CSV complete
# <DirEntry '211_North Carolina A&T_season_boxscores_2019.csv'>
# 211_North Carolina A&T_season_boxscores_2019.csv
# ["<DirEntry '211", "North Carolina A&T_season_boxscores_2019.csv'>"]
# North Carolina A&T_season_boxscores_2019.csv'>
# North Carolina A&T
# 2019
# getting team abbreviation
# NORTH-CAROLINA-AT
# dataframe complete
# North Carolina A&T  CSV complete
# <DirEntry '212_North Carolina Central_season_boxscores_2019.csv'>
# 212_North Carolina Central_season_boxscores_2019.csv
# ["<DirEntry '212", "North Carolina Central_season_boxscores_2019.csv'>"]
# North Carolina Central_season_boxscores_2019.csv'>
# North Carolina Central
# 2019
# getting team abbreviation
# NORTH-CAROLINA-CENTRAL
# dataframe complete
# North Carolina Central  CSV complete
# <DirEntry '213_UNC Greensboro_season_boxscores_2019.csv'>
# 213_UNC Greensboro_season_boxscores_2019.csv
# ["<DirEntry '213", "UNC Greensboro_season_boxscores_2019.csv'>"]
# UNC Greensboro_season_boxscores_2019.csv'>
# UNC Greensboro
# 2019
# getting team abbreviation
# NORTH-CAROLINA-GREENSBORO
# dataframe complete
# UNC Greensboro  CSV complete
# <DirEntry '214_NC State_season_boxscores_2019.csv'>
# 214_NC State_season_boxscores_2019.csv
# ["<DirEntry '214", "NC State_season_boxscores_2019.csv'>"]
# NC State_season_boxscores_2019.csv'>
# NC State
# 2019
# getting team abbreviation
# NORTH-CAROLINA-STATE
# dataframe complete
# NC State  CSV complete
# <DirEntry '215_UNC Wilmington_season_boxscores_2019.csv'>
# 215_UNC Wilmington_season_boxscores_2019.csv
# ["<DirEntry '215", "UNC Wilmington_season_boxscores_2019.csv'>"]
# UNC Wilmington_season_boxscores_2019.csv'>
# UNC Wilmington
# 2019
# getting team abbreviation
# NORTH-CAROLINA-WILMINGTON
# dataframe complete
# UNC Wilmington  CSV complete
# <DirEntry '216_North Carolina_season_boxscores_2019.csv'>
# 216_North Carolina_season_boxscores_2019.csv
# ["<DirEntry '216", "North Carolina_season_boxscores_2019.csv'>"]
# North Carolina_season_boxscores_2019.csv'>
# North Carolina
# 2019
# getting team abbreviation
# NORTH-CAROLINA
# dataframe complete
# North Carolina  CSV complete
# <DirEntry '217_North Dakota State_season_boxscores_2019.csv'>
# 217_North Dakota State_season_boxscores_2019.csv
# ["<DirEntry '217", "North Dakota State_season_boxscores_2019.csv'>"]
# North Dakota State_season_boxscores_2019.csv'>
# North Dakota State
# 2019
# getting team abbreviation
# NORTH-DAKOTA-STATE
# dataframe complete
# North Dakota State  CSV complete
# <DirEntry '218_North Dakota_season_boxscores_2019.csv'>
# 218_North Dakota_season_boxscores_2019.csv
# ["<DirEntry '218", "North Dakota_season_boxscores_2019.csv'>"]
# North Dakota_season_boxscores_2019.csv'>
# North Dakota
# 2019
# getting team abbreviation
# NORTH-DAKOTA
# dataframe complete
# North Dakota  CSV complete
# <DirEntry '219_North Florida_season_boxscores_2019.csv'>
# 219_North Florida_season_boxscores_2019.csv
# ["<DirEntry '219", "North Florida_season_boxscores_2019.csv'>"]
# North Florida_season_boxscores_2019.csv'>
# North Florida
# 2019
# getting team abbreviation
# NORTH-FLORIDA
# dataframe complete
# North Florida  CSV complete
# <DirEntry '21_Ball State_season_boxscores_2019.csv'>
# 21_Ball State_season_boxscores_2019.csv
# ["<DirEntry '21", "Ball State_season_boxscores_2019.csv'>"]
# Ball State_season_boxscores_2019.csv'>
# Ball State
# 2019
# getting team abbreviation
# BALL-STATE
# dataframe complete
# Ball State  CSV complete
# <DirEntry '220_North Texas_season_boxscores_2019.csv'>
# 220_North Texas_season_boxscores_2019.csv
# ["<DirEntry '220", "North Texas_season_boxscores_2019.csv'>"]
# North Texas_season_boxscores_2019.csv'>
# North Texas
# 2019
# getting team abbreviation
# NORTH-TEXAS
# dataframe complete
# North Texas  CSV complete
# <DirEntry '221_Northeastern_season_boxscores_2019.csv'>
# 221_Northeastern_season_boxscores_2019.csv
# ["<DirEntry '221", "Northeastern_season_boxscores_2019.csv'>"]
# Northeastern_season_boxscores_2019.csv'>
# Northeastern
# 2019
# getting team abbreviation
# NORTHEASTERN
# dataframe complete
# Northeastern  CSV complete
# <DirEntry '222_Northern Arizona_season_boxscores_2019.csv'>
# 222_Northern Arizona_season_boxscores_2019.csv
# ["<DirEntry '222", "Northern Arizona_season_boxscores_2019.csv'>"]
# Northern Arizona_season_boxscores_2019.csv'>
# Northern Arizona
# 2019
# getting team abbreviation
# NORTHERN-ARIZONA
# dataframe complete
# Northern Arizona  CSV complete
# <DirEntry '223_Northern Colorado_season_boxscores_2019.csv'>
# 223_Northern Colorado_season_boxscores_2019.csv
# ["<DirEntry '223", "Northern Colorado_season_boxscores_2019.csv'>"]
# Northern Colorado_season_boxscores_2019.csv'>
# Northern Colorado
# 2019
# getting team abbreviation
# NORTHERN-COLORADO
# dataframe complete
# Northern Colorado  CSV complete
# <DirEntry '224_Northern Illinois_season_boxscores_2019.csv'>
# 224_Northern Illinois_season_boxscores_2019.csv
# ["<DirEntry '224", "Northern Illinois_season_boxscores_2019.csv'>"]
# Northern Illinois_season_boxscores_2019.csv'>
# Northern Illinois
# 2019
# getting team abbreviation
# NORTHERN-ILLINOIS
# dataframe complete
# Northern Illinois  CSV complete
# <DirEntry '225_Northern Iowa_season_boxscores_2019.csv'>
# 225_Northern Iowa_season_boxscores_2019.csv
# ["<DirEntry '225", "Northern Iowa_season_boxscores_2019.csv'>"]
# Northern Iowa_season_boxscores_2019.csv'>
# Northern Iowa
# 2019
# getting team abbreviation
# NORTHERN-IOWA
# dataframe complete
# Northern Iowa  CSV complete
# <DirEntry '226_Northern Kentucky_season_boxscores_2019.csv'>
# 226_Northern Kentucky_season_boxscores_2019.csv
# ["<DirEntry '226", "Northern Kentucky_season_boxscores_2019.csv'>"]
# Northern Kentucky_season_boxscores_2019.csv'>
# Northern Kentucky
# 2019
# getting team abbreviation
# NORTHERN-KENTUCKY
# dataframe complete
# Northern Kentucky  CSV complete
# <DirEntry '227_Northwestern State_season_boxscores_2019.csv'>
# 227_Northwestern State_season_boxscores_2019.csv
# ["<DirEntry '227", "Northwestern State_season_boxscores_2019.csv'>"]
# Northwestern State_season_boxscores_2019.csv'>
# Northwestern State
# 2019
# getting team abbreviation
# NORTHWESTERN-STATE
# dataframe complete
# Northwestern State  CSV complete
# <DirEntry '228_Northwestern_season_boxscores_2019.csv'>
# 228_Northwestern_season_boxscores_2019.csv
# ["<DirEntry '228", "Northwestern_season_boxscores_2019.csv'>"]
# Northwestern_season_boxscores_2019.csv'>
# Northwestern
# 2019
# getting team abbreviation
# NORTHWESTERN
# dataframe complete
# Northwestern  CSV complete
# <DirEntry '229_Notre Dame_season_boxscores_2019.csv'>
# 229_Notre Dame_season_boxscores_2019.csv
# ["<DirEntry '229", "Notre Dame_season_boxscores_2019.csv'>"]
# Notre Dame_season_boxscores_2019.csv'>
# Notre Dame
# 2019
# getting team abbreviation
# NOTRE-DAME
# dataframe complete
# Notre Dame  CSV complete
# <DirEntry '22_Baylor_season_boxscores_2019.csv'>
# 22_Baylor_season_boxscores_2019.csv
# ["<DirEntry '22", "Baylor_season_boxscores_2019.csv'>"]
# Baylor_season_boxscores_2019.csv'>
# Baylor
# 2019
# getting team abbreviation
# BAYLOR
# dataframe complete
# Baylor  CSV complete
# <DirEntry '230_Oakland_season_boxscores_2019.csv'>
# 230_Oakland_season_boxscores_2019.csv
# ["<DirEntry '230", "Oakland_season_boxscores_2019.csv'>"]
# Oakland_season_boxscores_2019.csv'>
# Oakland
# 2019
# getting team abbreviation
# OAKLAND
# dataframe complete
# Oakland  CSV complete
# <DirEntry '231_Ohio State_season_boxscores_2019.csv'>
# 231_Ohio State_season_boxscores_2019.csv
# ["<DirEntry '231", "Ohio State_season_boxscores_2019.csv'>"]
# Ohio State_season_boxscores_2019.csv'>
# Ohio State
# 2019
# getting team abbreviation
# OHIO-STATE
# dataframe complete
# Ohio State  CSV complete
# <DirEntry '232_Ohio_season_boxscores_2019.csv'>
# 232_Ohio_season_boxscores_2019.csv
# ["<DirEntry '232", "Ohio_season_boxscores_2019.csv'>"]
# Ohio_season_boxscores_2019.csv'>
# Ohio
# 2019
# getting team abbreviation
# OHIO
# dataframe complete
# Ohio  CSV complete
# <DirEntry '233_Oklahoma State_season_boxscores_2019.csv'>
# 233_Oklahoma State_season_boxscores_2019.csv
# ["<DirEntry '233", "Oklahoma State_season_boxscores_2019.csv'>"]
# Oklahoma State_season_boxscores_2019.csv'>
# Oklahoma State
# 2019
# getting team abbreviation
# OKLAHOMA-STATE
# dataframe complete
# Oklahoma State  CSV complete
# <DirEntry '234_Oklahoma_season_boxscores_2019.csv'>
# 234_Oklahoma_season_boxscores_2019.csv
# ["<DirEntry '234", "Oklahoma_season_boxscores_2019.csv'>"]
# Oklahoma_season_boxscores_2019.csv'>
# Oklahoma
# 2019
# getting team abbreviation
# OKLAHOMA
# dataframe complete
# Oklahoma  CSV complete
# <DirEntry '235_Old Dominion_season_boxscores_2019.csv'>
# 235_Old Dominion_season_boxscores_2019.csv
# ["<DirEntry '235", "Old Dominion_season_boxscores_2019.csv'>"]
# Old Dominion_season_boxscores_2019.csv'>
# Old Dominion
# 2019
# getting team abbreviation
# OLD-DOMINION
# dataframe complete
# Old Dominion  CSV complete
# <DirEntry '236_Oral Roberts_season_boxscores_2019.csv'>
# 236_Oral Roberts_season_boxscores_2019.csv
# ["<DirEntry '236", "Oral Roberts_season_boxscores_2019.csv'>"]
# Oral Roberts_season_boxscores_2019.csv'>
# Oral Roberts
# 2019
# getting team abbreviation
# ORAL-ROBERTS
# dataframe complete
# Oral Roberts  CSV complete
# <DirEntry '237_Oregon State_season_boxscores_2019.csv'>
# 237_Oregon State_season_boxscores_2019.csv
# ["<DirEntry '237", "Oregon State_season_boxscores_2019.csv'>"]
# Oregon State_season_boxscores_2019.csv'>
# Oregon State
# 2019
# getting team abbreviation
# OREGON-STATE
# dataframe complete
# Oregon State  CSV complete
# <DirEntry '238_Oregon_season_boxscores_2019.csv'>
# 238_Oregon_season_boxscores_2019.csv
# ["<DirEntry '238", "Oregon_season_boxscores_2019.csv'>"]
# Oregon_season_boxscores_2019.csv'>
# Oregon
# 2019
# getting team abbreviation
# OREGON
# dataframe complete
# Oregon  CSV complete
# <DirEntry '239_Pacific_season_boxscores_2019.csv'>
# 239_Pacific_season_boxscores_2019.csv
# ["<DirEntry '239", "Pacific_season_boxscores_2019.csv'>"]
# Pacific_season_boxscores_2019.csv'>
# Pacific
# 2019
# getting team abbreviation
# PACIFIC
# dataframe complete
# Pacific  CSV complete
# <DirEntry '23_Belmont_season_boxscores_2019.csv'>
# 23_Belmont_season_boxscores_2019.csv
# ["<DirEntry '23", "Belmont_season_boxscores_2019.csv'>"]
# Belmont_season_boxscores_2019.csv'>
# Belmont
# 2019
# getting team abbreviation
# BELMONT
# dataframe complete
# Belmont  CSV complete
# <DirEntry '240_Penn State_season_boxscores_2019.csv'>
# 240_Penn State_season_boxscores_2019.csv
# ["<DirEntry '240", "Penn State_season_boxscores_2019.csv'>"]
# Penn State_season_boxscores_2019.csv'>
# Penn State
# 2019
# getting team abbreviation
# PENN-STATE
# dataframe complete
# Penn State  CSV complete
# <DirEntry '241_Pennsylvania_season_boxscores_2019.csv'>
# 241_Pennsylvania_season_boxscores_2019.csv
# ["<DirEntry '241", "Pennsylvania_season_boxscores_2019.csv'>"]
# Pennsylvania_season_boxscores_2019.csv'>
# Pennsylvania
# 2019
# getting team abbreviation
# PENNSYLVANIA
# dataframe complete
# Pennsylvania  CSV complete
# <DirEntry '242_Pepperdine_season_boxscores_2019.csv'>
# 242_Pepperdine_season_boxscores_2019.csv
# ["<DirEntry '242", "Pepperdine_season_boxscores_2019.csv'>"]
# Pepperdine_season_boxscores_2019.csv'>
# Pepperdine
# 2019
# getting team abbreviation
# PEPPERDINE
# dataframe complete
# Pepperdine  CSV complete
# <DirEntry '243_Pittsburgh_season_boxscores_2019.csv'>
# 243_Pittsburgh_season_boxscores_2019.csv
# ["<DirEntry '243", "Pittsburgh_season_boxscores_2019.csv'>"]
# Pittsburgh_season_boxscores_2019.csv'>
# Pittsburgh
# 2019
# getting team abbreviation
# PITTSBURGH
# ...
# ["<DirEntry '51", "Central Florida_season_boxscores_2019.csv'>"]
# Central Florida_season_boxscores_2019.csv'>
# Central Florida
# 2019
# getting team abbreviation
# CENTRAL-FLORIDA
# dataframe complete
# Central Florida  CSV complete
# <DirEntry '52_Central Michigan_season_boxscores_2019.csv'>
# 52_Central Michigan_season_boxscores_2019.csv
# ["<DirEntry '52", "Central Michigan_season_boxscores_2019.csv'>"]
# Central Michigan_season_boxscores_2019.csv'>
# Central Michigan
# 2019
# getting team abbreviation
# CENTRAL-MICHIGAN
# dataframe complete
# Central Michigan  CSV complete
# <DirEntry '53_Charleston Southern_season_boxscores_2019.csv'>
# 53_Charleston Southern_season_boxscores_2019.csv
# ["<DirEntry '53", "Charleston Southern_season_boxscores_2019.csv'>"]
# Charleston Southern_season_boxscores_2019.csv'>
# Charleston Southern
# 2019
# getting team abbreviation
# CHARLESTON-SOUTHERN
# dataframe complete
# Charleston Southern  CSV complete
# <DirEntry '54_Charlotte_season_boxscores_2019.csv'>
# 54_Charlotte_season_boxscores_2019.csv
# ["<DirEntry '54", "Charlotte_season_boxscores_2019.csv'>"]
# Charlotte_season_boxscores_2019.csv'>
# Charlotte
# 2019
# getting team abbreviation
# CHARLOTTE
# dataframe complete
# Charlotte  CSV complete
# <DirEntry '55_Chattanooga_season_boxscores_2019.csv'>
# 55_Chattanooga_season_boxscores_2019.csv
# ["<DirEntry '55", "Chattanooga_season_boxscores_2019.csv'>"]
# Chattanooga_season_boxscores_2019.csv'>
# Chattanooga
# 2019
# getting team abbreviation
# CHATTANOOGA
# dataframe complete
# Chattanooga  CSV complete
# <DirEntry '56_Chicago State_season_boxscores_2019.csv'>
# 56_Chicago State_season_boxscores_2019.csv
# ["<DirEntry '56", "Chicago State_season_boxscores_2019.csv'>"]
# Chicago State_season_boxscores_2019.csv'>
# Chicago State
# 2019
# getting team abbreviation
# CHICAGO-STATE
# dataframe complete
# Chicago State  CSV complete
# <DirEntry '57_Cincinnati_season_boxscores_2019.csv'>
# 57_Cincinnati_season_boxscores_2019.csv
# ["<DirEntry '57", "Cincinnati_season_boxscores_2019.csv'>"]
# Cincinnati_season_boxscores_2019.csv'>
# Cincinnati
# 2019
# getting team abbreviation
# CINCINNATI
# dataframe complete
# Cincinnati  CSV complete
# <DirEntry '58_The Citadel_season_boxscores_2019.csv'>
# 58_The Citadel_season_boxscores_2019.csv
# ["<DirEntry '58", "The Citadel_season_boxscores_2019.csv'>"]
# The Citadel_season_boxscores_2019.csv'>
# The Citadel
# 2019
# getting team abbreviation
# CITADEL
# dataframe complete
# The Citadel  CSV complete
# <DirEntry '59_Clemson_season_boxscores_2019.csv'>
# 59_Clemson_season_boxscores_2019.csv
# ["<DirEntry '59", "Clemson_season_boxscores_2019.csv'>"]
# Clemson_season_boxscores_2019.csv'>
# Clemson
# 2019
# getting team abbreviation
# CLEMSON
# dataframe complete
# Clemson  CSV complete
# <DirEntry '5_UAB_season_boxscores_2019.csv'>
# 5_UAB_season_boxscores_2019.csv
# ["<DirEntry '5", "UAB_season_boxscores_2019.csv'>"]
# UAB_season_boxscores_2019.csv'>
# UAB
# 2019
# getting team abbreviation
# ALABAMA-BIRMINGHAM
# dataframe complete
# UAB  CSV complete
# <DirEntry '60_Cleveland State_season_boxscores_2019.csv'>
# 60_Cleveland State_season_boxscores_2019.csv
# ["<DirEntry '60", "Cleveland State_season_boxscores_2019.csv'>"]
# Cleveland State_season_boxscores_2019.csv'>
# Cleveland State
# 2019
# getting team abbreviation
# CLEVELAND-STATE
# dataframe complete
# Cleveland State  CSV complete
# <DirEntry '61_Coastal Carolina_season_boxscores_2019.csv'>
# 61_Coastal Carolina_season_boxscores_2019.csv
# ["<DirEntry '61", "Coastal Carolina_season_boxscores_2019.csv'>"]
# Coastal Carolina_season_boxscores_2019.csv'>
# Coastal Carolina
# 2019
# getting team abbreviation
# COASTAL-CAROLINA
# dataframe complete
# Coastal Carolina  CSV complete
# <DirEntry '62_Colgate_season_boxscores_2019.csv'>
# 62_Colgate_season_boxscores_2019.csv
# ["<DirEntry '62", "Colgate_season_boxscores_2019.csv'>"]
# Colgate_season_boxscores_2019.csv'>
# Colgate
# 2019
# getting team abbreviation
# COLGATE
# dataframe complete
# Colgate  CSV complete
# <DirEntry '63_College of Charleston_season_boxscores_2019.csv'>
# 63_College of Charleston_season_boxscores_2019.csv
# ["<DirEntry '63", "College of Charleston_season_boxscores_2019.csv'>"]
# College of Charleston_season_boxscores_2019.csv'>
# College of Charleston
# 2019
# getting team abbreviation
# COLLEGE-OF-CHARLESTON
# dataframe complete
# College of Charleston  CSV complete
# <DirEntry '64_Colorado State_season_boxscores_2019.csv'>
# 64_Colorado State_season_boxscores_2019.csv
# ["<DirEntry '64", "Colorado State_season_boxscores_2019.csv'>"]
# Colorado State_season_boxscores_2019.csv'>
# Colorado State
# 2019
# getting team abbreviation
# COLORADO-STATE
# dataframe complete
# Colorado State  CSV complete
# <DirEntry '65_Colorado_season_boxscores_2019.csv'>
# 65_Colorado_season_boxscores_2019.csv
# ["<DirEntry '65", "Colorado_season_boxscores_2019.csv'>"]
# Colorado_season_boxscores_2019.csv'>
# Colorado
# 2019
# getting team abbreviation
# COLORADO
# dataframe complete
# Colorado  CSV complete
# <DirEntry '66_Columbia_season_boxscores_2019.csv'>
# 66_Columbia_season_boxscores_2019.csv
# ["<DirEntry '66", "Columbia_season_boxscores_2019.csv'>"]
# Columbia_season_boxscores_2019.csv'>
# Columbia
# 2019
# getting team abbreviation
# COLUMBIA
# dataframe complete
# Columbia  CSV complete
# <DirEntry '67_Connecticut_season_boxscores_2019.csv'>
# 67_Connecticut_season_boxscores_2019.csv
# ["<DirEntry '67", "Connecticut_season_boxscores_2019.csv'>"]
# Connecticut_season_boxscores_2019.csv'>
# Connecticut
# 2019
# getting team abbreviation
# CONNECTICUT
# dataframe complete
# Connecticut  CSV complete
# <DirEntry '68_Coppin State_season_boxscores_2019.csv'>
# 68_Coppin State_season_boxscores_2019.csv
# ["<DirEntry '68", "Coppin State_season_boxscores_2019.csv'>"]
# Coppin State_season_boxscores_2019.csv'>
# Coppin State
# 2019
# getting team abbreviation
# COPPIN-STATE
# dataframe complete
# Coppin State  CSV complete
# <DirEntry '69_Cornell_season_boxscores_2019.csv'>
# 69_Cornell_season_boxscores_2019.csv
# ["<DirEntry '69", "Cornell_season_boxscores_2019.csv'>"]
# Cornell_season_boxscores_2019.csv'>
# Cornell
# 2019
# getting team abbreviation
# CORNELL
# dataframe complete
# Cornell  CSV complete
# <DirEntry '6_Alabama State_season_boxscores_2019.csv'>
# 6_Alabama State_season_boxscores_2019.csv
# ["<DirEntry '6", "Alabama State_season_boxscores_2019.csv'>"]
# Alabama State_season_boxscores_2019.csv'>
# Alabama State
# 2019
# getting team abbreviation
# ALABAMA-STATE
# dataframe complete
# Alabama State  CSV complete
# <DirEntry '70_Creighton_season_boxscores_2019.csv'>
# 70_Creighton_season_boxscores_2019.csv
# ["<DirEntry '70", "Creighton_season_boxscores_2019.csv'>"]
# Creighton_season_boxscores_2019.csv'>
# Creighton
# 2019
# getting team abbreviation
# CREIGHTON
# dataframe complete
# Creighton  CSV complete
# <DirEntry '71_Dartmouth_season_boxscores_2019.csv'>
# 71_Dartmouth_season_boxscores_2019.csv
# ["<DirEntry '71", "Dartmouth_season_boxscores_2019.csv'>"]
# Dartmouth_season_boxscores_2019.csv'>
# Dartmouth
# 2019
# getting team abbreviation
# DARTMOUTH
# dataframe complete
# Dartmouth  CSV complete
# <DirEntry '72_Davidson_season_boxscores_2019.csv'>
# 72_Davidson_season_boxscores_2019.csv
# ["<DirEntry '72", "Davidson_season_boxscores_2019.csv'>"]
# Davidson_season_boxscores_2019.csv'>
# Davidson
# 2019
# getting team abbreviation
# DAVIDSON
# dataframe complete
# Davidson  CSV complete
# <DirEntry '73_Dayton_season_boxscores_2019.csv'>
# 73_Dayton_season_boxscores_2019.csv
# ["<DirEntry '73", "Dayton_season_boxscores_2019.csv'>"]
# Dayton_season_boxscores_2019.csv'>
# Dayton
# 2019
# getting team abbreviation
# DAYTON
# dataframe complete
# Dayton  CSV complete
# <DirEntry '74_Delaware State_season_boxscores_2019.csv'>
# 74_Delaware State_season_boxscores_2019.csv
# ["<DirEntry '74", "Delaware State_season_boxscores_2019.csv'>"]
# Delaware State_season_boxscores_2019.csv'>
# Delaware State
# 2019
# getting team abbreviation
# DELAWARE-STATE
# dataframe complete
# Delaware State  CSV complete
# <DirEntry '75_Delaware_season_boxscores_2019.csv'>
# 75_Delaware_season_boxscores_2019.csv
# ["<DirEntry '75", "Delaware_season_boxscores_2019.csv'>"]
# Delaware_season_boxscores_2019.csv'>
# Delaware
# 2019
# getting team abbreviation
# DELAWARE
# dataframe complete
# Delaware  CSV complete
# <DirEntry '76_Denver_season_boxscores_2019.csv'>
# 76_Denver_season_boxscores_2019.csv
# ["<DirEntry '76", "Denver_season_boxscores_2019.csv'>"]
# Denver_season_boxscores_2019.csv'>
# Denver
# 2019
# getting team abbreviation
# DENVER
# dataframe complete
# Denver  CSV complete
# <DirEntry '77_DePaul_season_boxscores_2019.csv'>
# 77_DePaul_season_boxscores_2019.csv
# ["<DirEntry '77", "DePaul_season_boxscores_2019.csv'>"]
# DePaul_season_boxscores_2019.csv'>
# DePaul
# 2019
# getting team abbreviation
# DEPAUL
# dataframe complete
# DePaul  CSV complete
# <DirEntry '78_Detroit Mercy_season_boxscores_2019.csv'>
# 78_Detroit Mercy_season_boxscores_2019.csv
# ["<DirEntry '78", "Detroit Mercy_season_boxscores_2019.csv'>"]
# Detroit Mercy_season_boxscores_2019.csv'>
# Detroit Mercy
# 2019
# getting team abbreviation
# DETROIT-MERCY
# dataframe complete
# Detroit Mercy  CSV complete
# <DirEntry '79_Drake_season_boxscores_2019.csv'>
# 79_Drake_season_boxscores_2019.csv
# ["<DirEntry '79", "Drake_season_boxscores_2019.csv'>"]
# Drake_season_boxscores_2019.csv'>
# Drake
# 2019
# getting team abbreviation
# DRAKE
# dataframe complete
# Drake  CSV complete
# <DirEntry '7_Alabama_season_boxscores_2019.csv'>
# 7_Alabama_season_boxscores_2019.csv
# ["<DirEntry '7", "Alabama_season_boxscores_2019.csv'>"]
# Alabama_season_boxscores_2019.csv'>
# Alabama
# 2019
# getting team abbreviation
# ALABAMA
# dataframe complete
# Alabama  CSV complete
# <DirEntry '80_Drexel_season_boxscores_2019.csv'>
# 80_Drexel_season_boxscores_2019.csv
# ["<DirEntry '80", "Drexel_season_boxscores_2019.csv'>"]
# Drexel_season_boxscores_2019.csv'>
# Drexel
# 2019
# getting team abbreviation
# DREXEL
# dataframe complete
# Drexel  CSV complete
# <DirEntry '81_Duke_season_boxscores_2019.csv'>
# 81_Duke_season_boxscores_2019.csv
# ["<DirEntry '81", "Duke_season_boxscores_2019.csv'>"]
# Duke_season_boxscores_2019.csv'>
# Duke
# 2019
# getting team abbreviation
# DUKE
# dataframe complete
# Duke  CSV complete
# <DirEntry '82_Duquesne_season_boxscores_2019.csv'>
# 82_Duquesne_season_boxscores_2019.csv
# ["<DirEntry '82", "Duquesne_season_boxscores_2019.csv'>"]
# Duquesne_season_boxscores_2019.csv'>
# Duquesne
# 2019
# getting team abbreviation
# DUQUESNE
# dataframe complete
# Duquesne  CSV complete
# <DirEntry '83_East Carolina_season_boxscores_2019.csv'>
# 83_East Carolina_season_boxscores_2019.csv
# ["<DirEntry '83", "East Carolina_season_boxscores_2019.csv'>"]
# East Carolina_season_boxscores_2019.csv'>
# East Carolina
# 2019
# getting team abbreviation
# EAST-CAROLINA
# dataframe complete
# East Carolina  CSV complete
# <DirEntry '84_East Tennessee State_season_boxscores_2019.csv'>
# 84_East Tennessee State_season_boxscores_2019.csv
# ["<DirEntry '84", "East Tennessee State_season_boxscores_2019.csv'>"]
# East Tennessee State_season_boxscores_2019.csv'>
# East Tennessee State
# 2019
# getting team abbreviation
# EAST-TENNESSEE-STATE
# dataframe complete
# East Tennessee State  CSV complete
# <DirEntry '85_Eastern Illinois_season_boxscores_2019.csv'>
# 85_Eastern Illinois_season_boxscores_2019.csv
# ["<DirEntry '85", "Eastern Illinois_season_boxscores_2019.csv'>"]
# Eastern Illinois_season_boxscores_2019.csv'>
# Eastern Illinois
# 2019
# getting team abbreviation
# EASTERN-ILLINOIS
# dataframe complete
# Eastern Illinois  CSV complete
# <DirEntry '86_Eastern Kentucky_season_boxscores_2019.csv'>
# 86_Eastern Kentucky_season_boxscores_2019.csv
# ["<DirEntry '86", "Eastern Kentucky_season_boxscores_2019.csv'>"]
# Eastern Kentucky_season_boxscores_2019.csv'>
# Eastern Kentucky
# 2019
# getting team abbreviation
# EASTERN-KENTUCKY
# dataframe complete
# Eastern Kentucky  CSV complete
# <DirEntry '87_Eastern Michigan_season_boxscores_2019.csv'>
# 87_Eastern Michigan_season_boxscores_2019.csv
# ["<DirEntry '87", "Eastern Michigan_season_boxscores_2019.csv'>"]
# Eastern Michigan_season_boxscores_2019.csv'>
# Eastern Michigan
# 2019
# getting team abbreviation
# EASTERN-MICHIGAN
# dataframe complete
# Eastern Michigan  CSV complete
# <DirEntry '88_Eastern Washington_season_boxscores_2019.csv'>
# 88_Eastern Washington_season_boxscores_2019.csv
# ["<DirEntry '88", "Eastern Washington_season_boxscores_2019.csv'>"]
# Eastern Washington_season_boxscores_2019.csv'>
# Eastern Washington
# 2019
# getting team abbreviation
# EASTERN-WASHINGTON
# dataframe complete
# Eastern Washington  CSV complete
# <DirEntry '89_Elon_season_boxscores_2019.csv'>
# 89_Elon_season_boxscores_2019.csv
# ["<DirEntry '89", "Elon_season_boxscores_2019.csv'>"]
# Elon_season_boxscores_2019.csv'>
# Elon
# 2019
# getting team abbreviation
# ELON
# dataframe complete
# Elon  CSV complete
# <DirEntry '8_Albany (NY)_season_boxscores_2019.csv'>
# 8_Albany (NY)_season_boxscores_2019.csv
# ["<DirEntry '8", "Albany (NY)_season_boxscores_2019.csv'>"]
# Albany (NY)_season_boxscores_2019.csv'>
# Albany (NY)
# 2019
# getting team abbreviation
# ALBANY-NY
# dataframe complete
# Albany (NY)  CSV complete
# <DirEntry '90_Evansville_season_boxscores_2019.csv'>
# 90_Evansville_season_boxscores_2019.csv
# ["<DirEntry '90", "Evansville_season_boxscores_2019.csv'>"]
# Evansville_season_boxscores_2019.csv'>
# Evansville
# 2019
# getting team abbreviation
# EVANSVILLE
# dataframe complete
# Evansville  CSV complete
# <DirEntry '91_Fairfield_season_boxscores_2019.csv'>
# 91_Fairfield_season_boxscores_2019.csv
# ["<DirEntry '91", "Fairfield_season_boxscores_2019.csv'>"]
# Fairfield_season_boxscores_2019.csv'>
# Fairfield
# 2019
# getting team abbreviation
# FAIRFIELD
# dataframe complete
# Fairfield  CSV complete
# <DirEntry '92_Fairleigh Dickinson_season_boxscores_2019.csv'>
# 92_Fairleigh Dickinson_season_boxscores_2019.csv
# ["<DirEntry '92", "Fairleigh Dickinson_season_boxscores_2019.csv'>"]
# Fairleigh Dickinson_season_boxscores_2019.csv'>
# Fairleigh Dickinson
# 2019
# getting team abbreviation
# FAIRLEIGH-DICKINSON
# dataframe complete
# Fairleigh Dickinson  CSV complete
# <DirEntry '93_Florida A&M_season_boxscores_2019.csv'>
# 93_Florida A&M_season_boxscores_2019.csv
# ["<DirEntry '93", "Florida A&M_season_boxscores_2019.csv'>"]
# Florida A&M_season_boxscores_2019.csv'>
# Florida A&M
# 2019
# getting team abbreviation
# FLORIDA-AM
# dataframe complete
# Florida A&M  CSV complete
# <DirEntry '94_Florida Atlantic_season_boxscores_2019.csv'>
# 94_Florida Atlantic_season_boxscores_2019.csv
# ["<DirEntry '94", "Florida Atlantic_season_boxscores_2019.csv'>"]
# Florida Atlantic_season_boxscores_2019.csv'>
# Florida Atlantic
# 2019
# getting team abbreviation
# FLORIDA-ATLANTIC
# dataframe complete
# Florida Atlantic  CSV complete
# <DirEntry '95_Florida Gulf Coast_season_boxscores_2019.csv'>
# 95_Florida Gulf Coast_season_boxscores_2019.csv
# ["<DirEntry '95", "Florida Gulf Coast_season_boxscores_2019.csv'>"]
# Florida Gulf Coast_season_boxscores_2019.csv'>
# Florida Gulf Coast
# 2019
# getting team abbreviation
# FLORIDA-GULF-COAST
# dataframe complete
# Florida Gulf Coast  CSV complete
# <DirEntry '96_Florida International_season_boxscores_2019.csv'>
# 96_Florida International_season_boxscores_2019.csv
# ["<DirEntry '96", "Florida International_season_boxscores_2019.csv'>"]
# Florida International_season_boxscores_2019.csv'>
# Florida International
# 2019
# getting team abbreviation
# FLORIDA-INTERNATIONAL
# dataframe complete
# Florida International  CSV complete
# <DirEntry '97_Florida State_season_boxscores_2019.csv'>
# 97_Florida State_season_boxscores_2019.csv
# ["<DirEntry '97", "Florida State_season_boxscores_2019.csv'>"]
# Florida State_season_boxscores_2019.csv'>
# Florida State
# 2019
# getting team abbreviation
# FLORIDA-STATE
# dataframe complete
# Florida State  CSV complete
# <DirEntry '98_Florida_season_boxscores_2019.csv'>
# 98_Florida_season_boxscores_2019.csv
# ["<DirEntry '98", "Florida_season_boxscores_2019.csv'>"]
# Florida_season_boxscores_2019.csv'>
# Florida
# 2019
# getting team abbreviation
# FLORIDA
# dataframe complete
# Florida  CSV complete
# <DirEntry '99_Fordham_season_boxscores_2019.csv'>
# 99_Fordham_season_boxscores_2019.csv
# ["<DirEntry '99", "Fordham_season_boxscores_2019.csv'>"]
# Fordham_season_boxscores_2019.csv'>
# Fordham
# 2019
# getting team abbreviation
# FORDHAM
# dataframe complete
# Fordham  CSV complete
# <DirEntry '9_Alcorn State_season_boxscores_2019.csv'>
# 9_Alcorn State_season_boxscores_2019.csv
# ["<DirEntry '9", "Alcorn State_season_boxscores_2019.csv'>"]
# Alcorn State_season_boxscores_2019.csv'>
# Alcorn State
# 2019
# getting team abbreviation
# ALCORN-STATE
# dataframe complete
# Alcorn State  CSV complete

# %%
#All of the below cell is to play around
#directory = '../data/team_csvs/2019-2020/'
#filename = '283_South Florida_season_boxscores_2019.csv'
#teamschedule_df = pd.read_csv(directory + filename)

#filename variable is an nt.DirEntry type. We need to convert it to string
#file_name = str(filename)
#print(file_name)

# Now, we need to slice the string in a sustainable way. We'll slice out everything up to and including the first underscore
#file_name = file_name.split('_', 1)
#print(file_name)

#file_name = file_name[1]
#print(file_name)
#next we extract team name and season - we know that everything after the name is constant for all files
#team_name = file_name[:-26]
#season = file_name[-8:-4]
#print(team_name)
#print(season)
#print('getting team abbreviation')

#for team in Teams(season):
#    if team.name == team_name:
#        abbrev = team.abbreviation
#        break

#print (abbrev)
#teamschedule_df.rename(columns={'Unnamed: 0': 'boxscore'}, inplace=True)
#teamschedule_df['game_number'] = teamschedule_df.index

# Conditional column - we have a pair of criteria that tell us if a given game is home based on the winner of the game (home vs. away) and 
# the abbreviation of the winning team
#teamschedule_df['{}_homegame'.format(abbrev)] = (teamschedule_df['winner'] == 'Home') & (teamschedule_df['winning_abbr'] == abbrev)
#teamschedule_df['{}_homegame2'.format(abbrev)] = (teamschedule_df['winner'] == 'Away') & (teamschedule_df['winning_abbr'] != abbrev)

# set team_abbrev_home to True if either of the home game criteria that we ran above are true
#teamschedule_df['{}_home'.format(abbrev)] = (teamschedule_df['{}_homegame'.format(abbrev)] == True) | (teamschedule_df['{}_homegame2'.format(abbrev)] == True)

# Make the game location (from perspective of the team) equal to Home if the team_abbrev_home column is True, otherwise make it away
#teamschedule_df['{}_location'.format(abbrev)] = teamschedule_df.apply(lambda x: 'Home' if x['{}_home'.format(abbrev)] == True else 'Away', axis=1)

# Set each game stat equal to the home team stat if they played at home, otherwise set to the away team stat
#teamschedule_df['total_threes_made'] = teamschedule_df.apply(lambda x: x['home_three_point_field_goals'] if x['{}_home'.format(abbrev)] == True else x['away_three_point_field_goals'], axis=1)
#teamschedule_df['total_fg_made'] = teamschedule_df.apply(lambda x: x['home_field_goals'] if x['{}_home'.format(abbrev)] == True else x['away_field_goals'], axis=1)
#teamschedule_df['total_fg_attempts'] = teamschedule_df.apply(lambda x: x['home_field_goal_attempts'] if x['{}_home'.format(abbrev)] == True else x['away_field_goal_attempts'], axis=1)

#calculate the cumulative pregame stats heading in to each game
#teamschedule_df['pregame_total_threes_made'] = teamschedule_df.total_threes_made.cumsum() - teamschedule_df.total_threes_made
#teamschedule_df['pregame_total_fg_made'] = teamschedule_df.total_fg_made.cumsum() - teamschedule_df.total_fg_made
#teamschedule_df['pregame_total_fg_attempts'] = teamschedule_df.total_fg_attempts.cumsum() - teamschedule_df.total_fg_attempts

#calculate the actual target statistic which is eFG 
#teamschedule_df['pregame_eFG'] = (teamschedule_df.pregame_total_fg_made + (teamschedule_df.pregame_total_threes_made / 2)) / teamschedule_df.pregame_total_fg_attempts
# (2PM + .5 * 3PM) / FGA
#print('dataframe complete')
#teamschedule_df.to_csv('../data/team_csvs/2019-2020/{}'.format(filename))
#print(team_name, ' CSV complete')

# %%
teamschedule_df.head()

# %%
teamschedule_df.head()

# %%
teamschedule_df.head()

# %%
#each team's csv should have that team's rolling stats in the CSV. Then, for each game in the giant boxscore DF, 
# I can go grab the team's pregame eFG for that particular game number. Would prob have to index on boxscore uri
